# %% [markdown]
# ## In-Class Guided Exercise:
# :
#
# ![image-2.png](attachment:image-2.png)
#
# Let us web scrape Namshi site

# %% [markdown]
# ### Import needed libraries

# %%
import requests
import httpx  # if you want to use httpx instead of requests

import pandas as pd
from bs4 import BeautifulSoup
from time import sleep

# %% [markdown]
# ### Steps on using BeautifulSoup:
# #### 1. Use `requests` to access the url of the web page you want to scrape

# %%
url='https://www.namshi.com/bahrain-en/kids-shoes-boys/?page=1'

# %%
# html_page = requests.get(url)


# if you get error or run forever, then:
# 1. Stop or kill the kernel
# 2. comment the above line
# 3. uncomment the below two lines 
# 4. run everything from the begining including this cell 

hdr={"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 YaBrowser/23.3.0.1922 (beta) Yowser/2.5 Safari/537.3-449"}
html_page = requests.get(url,headers=hdr)

# %%
# check the status code if it is 200 then everthing is OK
html_page.status_code
# 200 mean OK
# Out:
# 200

# %% [markdown]
# #### 2. Now that we have the web page, we can parse it with beautifulsoup:

# %%
soup = BeautifulSoup(html_page.text, 'html.parser')

# %% [markdown]
# - Get the title of the page using the tag 'title':

# %%
soup.title.text
# Out:
# "Boys' Shoes Bahrain | Best Price Offers | Manama, Riffa"

# %% [markdown]
# #### 3. Get all the items in that page
# - Use `inspect` on the web page to know how to collect the items
# - Create a variable that contains all the items in that web page

# %%
namshi = soup.find_all("div",class_="ProductBox_container__wiajf ProductBox_boxContainer__p7PaQ")

# %%
# check one of the items collected
namshi[0]
# Out:
# <div class="ProductBox_container__wiajf ProductBox_boxContainer__p7PaQ"><a class="ProductBox_container__wiajf" href="/bahrain-en/buy-jordan-jordan-flight-court/Z4EE061159A21B01428F2Z/p/"><div class="ProductBox_imageContainer__qrIJP"><div class="ProductBox_productBadgeContainer__WbLpW"><section class="ProductBadge_container__m6RwS ProductBadge_regular__n49O_">Premium</section></div><div><section><div class="EmblaCarousel_outerWrapper__wzwd8"><div class="EmblaCarousel_wrapper__ndTTF"><div class="EmblaCarousel_container__MkuxD"><div class="EmblaCarousel_carouselContainer__C7YLK"><div class="EmblaCarousel_slidesContainer__NYcld"><div style="flex:0 0 calc(100%)"><div class="ProductImage_imageContainer__B5pcR"><img alt="Jordan Jordan Flight Court" class="ProductImage_image__Gv0_w ProductImage_outlined__NEzjp" data-nimg="1" decoding="async" fetchpriority="high" height="1091" loading="eager" src="https://f.nooncdn.com/p/pzsku/Z4EE061159A21B01428F2Z/45/1765205848/e62c9235-8cad-4c1e-a9fe-16753aef8227.jpg?format=webp&amp;width=800" style="color:transparent;background-image:url(https://f.nooncdn.com/s/app/2025/nm-namshi-frontend/f81167559b030e2eff35e904f9f3841169620b01/bigalog/_next/_static/_next/static/media/placeholder.834bb8d5.svg)" width="800"/></div></div><div style="flex:0 0 calc(100%)"><div class="ProductImage_imageContainer__B5pcR"><img alt="Jordan Jordan Flight Court" class="ProductImage_image__Gv0_w ProductImage_outlined__NEzjp" data-nimg="1" decoding="async" fetchpriority="auto" height="1091" loading="lazy" src="https://f.nooncdn.com/p/pzsku/Z4EE061159A21B01428F2Z/45/1765205848/141c15ba-db05-4ea9-aa6d-d5edccf7f4a2.jpg?format=webp&amp;width=800" style="color:transparent;background-image:url(https://f.nooncdn.com/s/app/2025/nm-namshi-frontend/f81167559b030e2eff35e904f9f3841169620b01/bigalog/_next/_static/_next/static/media/placeholder.834bb8d5.svg)" width="800"/></div></div><div style="flex:0 0 calc(100%)"></div><div style="flex:0 0 calc(100%)"></div></div></div></div></div></div></section></div></div><div class="ProductBox_detailsWrapper__1WQLj"><div class="ProductBox_detailsContainer__LX4rf"><div class="ProductBox_detailsHeader__bhHM2"><div><div class="OutletAndBrand_brandAndOutletTag__eEj4l">Jordan</div><div class="ProductBox_productTitle__6tQ3b" title="Jordan Flight Court">Jordan Flight Court</div></div></div><section class="ProductPrice_container__LDerj"><span class="ProductPrice_sellingPrice__injLG ProductPrice_large__e_5W8" dir="ltr"><span class="ProductPrice_currency__zHaox" dir="ltr">BHD</span><span class="ProductPrice_value__YcE7Z">46.55</span></span></section><div class="RotatingElements_container__cS80Q" style="--frame-height:16px;--offset-frame-height:-16px;--rotate-duration:2500ms"><div>Free delivery</div></div></div><div><button class="HeartIcon_container__ZzT7u HeartIcon_btn__t5VmL" type="button"><img alt="wishlist" class="Icon_icon__CKnc0 Icon_black__r89Oj --namshi-icon" color="black" data-nimg="1" decoding="async" height="24" loading="eager" src="https://f.nooncdn.com/s/app/com/namshi/icons-v3/wishlist.svg" style="color:transparent;min-width:24px" width="24"/></button></div></div></a></div>

# %% [markdown]
# #### 4. Using one item, try to collect the information that you want to scrape
# - In our web page here, we want to collect the following:
#     - Product Title
#     - Brand
#     - Price
#     - Currency
#     - PreReduction Price
#     - Discount

# %% [markdown]
# ##### 4.1 *Get the Product Title*

# %%
namshi[0].find("div",class_="ProductBox_productTitle__6tQ3b").text
# Out:
# 'Youth 530'

# %% [markdown]
# ##### 4.2 *Get the Brand*

# %%
namshi[0].find("div", class_="OutletAndBrand_brandAndOutletTag__eEj4l").text
# Out:
# 'New Balance'

# %% [markdown]
# ##### 4.3 *Get the Price*

# %%
namshi[0].find("span", class_="ProductPrice_value__YcE7Z").text
# Out:
# '52.25'

# %% [markdown]
# ##### 4.4 *Get the Currency*

# %%
namshi[0].find("span", class_="ProductPrice_currency__zHaox").text
# Out:
# 'BHD'

# %% [markdown]
# ##### 4.5 *Get the PreReduction Price*

# %%
namshi[2].find("div", class_="ProductPrice_preReductionPrice__oM4c9")

# %% [markdown]
# ##### 4.6 *Get the Discount*

# %%
namshi[9].find("span", class_="DiscountTag_value__SofQj")

# %% [markdown]
# #### 5. Collect all the information of all the items using `loops`
# - Now, once we know how to get in information we want from one item, we can now collect all the information from all the items using `for loop`
# - First of all, we need to create a list for each info we want to collect and append the scraped info to those lists

# %%
# define empty lists for your collections
titles = []
brands = []
prices = []
currencies = []
prereduction_prices = []
discounts = []

# your code here
for item in namshi:
    title = item.find("div", class_="ProductBox_productTitle__6tQ3b")
    if title is not None:
        titles.append(title.text)
    else:
        titles.append(None)

    
    brand = item.find("div", class_="OutletAndBrand_brandAndOutletTag__eEj4l")
    if brand is not None:
        brands.append(brand.text)
    else:
        brands.append(None)

    price = item.find("span", class_="ProductPrice_value__YcE7Z")
    if price is not None:
        prices.append(price.text)
    else:
        prices.append(None)

    currency = item.find("span", class_="ProductPrice_currency__zHaox")
    if currency is not None:
        currencies.append(currency.text)
    else:
        currencies.append(None)

   
    prereduction = item.find("div", class_="ProductPrice_preReductionPrice__oM4c9")

    if prereduction is not None:
        prereduction_prices.append(prereduction.text)
    else:
        prereduction_prices.append(None)


    discount = item.find("span", class_="DiscountTag_value__SofQj")
    if discount is not None:
        discounts.append(discount.text)
    else:
        discounts.append(None)

# %%
# check what one of the lists contains
titles
# Out:
# ['Youth 530',
#  'Kids Breakbase',
#  'Youth Copa Pure IV Club IN',
#  'Tensaur Switch Shoes Kids',
#  'Kids Handball Spezial',
#  'Youth Gel-Nyc Gs',
#  'Kids Copa Pure Iv League Tf',
#  'Kids Campus 00S C',
#  'Youth 408',
#  'Tensaur Comfort Shoes Kids',
#  'Youth Runfalcon 5',
#  'Youth Deportivo III TF',
#  'Air Jordan 1 Mid',
#  'Kids Runfalcon 5 El',
#  'Youth Gazelle',
#  'Kids Chuck Taylor All Star',
#  'AIR MAX 270 BG',
#  'Youth Tensaur Run 3.0',
#  'Kids Chuck Taylor All Star',
#  'Youth Runfalcon 5 El',
#  'Nike Jr. Tiempo Legend 10 Academy',
#  'Youth Softride Cosmic Street Sliptech',
#  'Youth Terrain Clogs',
#  'Infant Samba Og Cf El',
#  'Youth Handball Spezial',
#  'Air Jordan 1 Mid',
#  'Kids Runfalcon 5 El',
#  'Infant Samba Og Cf El',
#  'Youth Rickie',
#  'Kids Samba Og',
#  'NIKE STAR RUNNER 5 GS',
#  'Tensaur Comfort Shoes Kids',
#  'Kids Bounder',
#  'Infant Vl Court 3.0 Cf',
#  'Youth Gel-Nyc Gs',
#  'Youth Gazelle',
#  'Infant Duramo Sl2 El',
#  'Kids Go Run 400 V2',
#  'Kids Duramo Sl2 El C',
#  'Infant Grand Court Mickey',
#  'Infant Runfalcon 5 El',
#  'Kids Chuck Taylor All Star',
#  'Kids Barreda Decode Elsa',
#  'Kids Duramo Sl2 El',
#  'Kids Campus 00S El C',
#  'Kids Grand Court Spider-Man',
#  'Youth 530',
#  "Youth Gs Jet '25",
#  'Kids Tensaur Comfort Ac',
#  'Infant Adilette Estrap Buz',
#  'Kids Campus 00S C',
#  'Youth Advantage Base 2.0',
#  'Youth Grand Court 3.0',
#  'Youth Handball Spezial',
#  'Youth Fortarun 4.0',
#  'Kids Duramo Sl2 El',
#  'Kids Bounder',
#  'Kids Grand Court Capt America El',
#  'Infant Samba Crib',
#  'Youth Runfalcon 5',
#  'Kids Grand Court Spider-Man',
#  'Kids Club Ii Era V Ps',
#  'AIR MAX 270 BG',
#  'Youth Tensaur Run 3.0',
#  'Kids Handball Spezial',
#  'Infant Vl Court 3.0 Cf',
#  'NIKE V5 RNR E BP',
#  'Kids Adifom Samba 360 C',
#  'Youth Barreda Decode',
#  'Kids Grand Court Capt America El',
#  'Kids Tensaur Comfort Ac',
#  'Kids All-Day Active Ac+ Ps',
#  'Kids Club Ii Era',
#  'Kids Smash 3.0 L V Ps',
#  'Youth Runfalcon 5',
#  'Unisex Kids BMW M Motorsport Drift Cat Decima motorsport shoe',
#  'Kids Smash 3.0 L V Ps',
#  'Kids Trinity 2 Lt',
#  'Infant Campus 00S Cf El',
#  'Nike Metro Tek',
#  'Kids Grand Court Minnie',
#  'Kids Handball Spezial',
#  'Kids Flexfocus Sliptech Ps',
#  'Kids Water Sandal Spider',
#  'Kids Rincon 4 Big Kids',
#  'Infant Tensaur Comfort Ac',
#  "Youth Gs Jet '25",
#  'Youth Adizero Evo Sl',
#  'Infant Gazellef El',
#  'Kids Vl Court 3.0',
#  'Infant Tensaur Switch Cf',
#  'Kids Samba Og Cf El C',
#  'Kids Classic Clogs',
#  'Kids Tensaur Run 3.0 El',
#  'Kids Breakbase C',
#  'Youth Runfalcon 5 El',
#  'Nike Jr. Tiempo Legend 10 Academy',
#  'Kids Gel-1130 Ps',
#  'Infant Bubblecomfy',
#  'Youth Softride Cosmic Street Sliptech',
#  'Kids Gel-1130 Ps',
#  'Kids Tensaur Run 3.0 El',
#  'Kids Club Ii Era',
#  'Kids Runfalcon 5 El',
#  'Kids Smash 3.0 L V Ps',
#  'NIKE COSMIC RUNNER TD',
#  'Youth Runfalcon 5',
#  'Infant Flexfocus Modern Ac+',
#  'Kids Gel-1130 Ps',
#  'Nike Flex Runner 4',
#  'Kids Altaswim 3 C',
#  'Kids Adifom Samba 360 C',
#  'Youth Cloud Play',
#  'Unisex Kids BMW M Motorsport Drift Cat Decima motorsport shoe',
#  'Kids Smash 3.0 L V Ps',
#  'Kids Sunray Protect 4 Bp',
#  'Infant Breaknet 3.0 Cf',
#  'Kids Trinity 2 Lt',
#  'Kids Vl Court 3.0',
#  'Kids Gel-1130 Ps',
#  'Youth V5 Rnr Gs',
#  'Infant Tensaur Run 3.0 El',
#  'Kids Handball Spezial',
#  'Kids Crocband Cruiser Sandals',
#  'Infant Summerflex I',
#  'Nike Flex Runner 4',
#  'Nike Metro Tek',
#  'Youth Samba Og',
#  'Infant Tensaur Run 3.0 El',
#  'Kids Grand Court Minnie',
#  'Kids Adilette Shower Logo',
#  'Kids Adifom Samba 360 C',
#  'Kids Pokemon Print Classic Clog',
#  'Kids Adilette Aqua',
#  'Youth Tensaur Switch',
#  'Youth Anzarun Lite',
#  'Kids Old Skool V Sneakers',
#  'Youth Omni Multi-Court Gs',
#  'Youth Air Max Fire Gs',
#  'Kids Fun Racer 2 Ac+ Ps',
#  'Infant Adifom Samba 360 I',
#  "Kids' Black Velcro Strap Sneakers Shoes - Easy-On, Day Fun for Little Explorers!",
#  'Nike Air Max SC',
#  'Infant Fun Racer 2 Ac+',
#  'Nike Dunk Low',
#  'Infant Star Runner 5 Td',
#  'Youth Grand Court 3.0',
#  'COURT BOROUGH MID 2 BPV',
#  'Kids Duramo Sl2 El',
#  'Kids Tensaur Run 3.0 El',
#  'Kids Air Max 270 Bp',
#  'Youth Air Jordan 1 Mid Bg',
#  'Adilette Sandals',
#  'Youth Anzarun Lite',
#  'Infant Samba Og Cf El',
#  'Kids Old Skool V Sneakers',
#  'Youth Omni Multi-Court Gs',
#  'Youth Gel-1130 Gs',
#  'Kids Go Run 400 V2',
#  'Kids Samba Og',
#  'Infant Grand Court 2.0',
#  'Nike Flex Runner 4',
#  'Kids Deportivo Iii Tf',
#  'Infant Handball Spezial Cf',
#  'Tensaur Hook and Loop Shoes',
#  'COURT BOROUGH LOW RECRAFT BPV',
#  'Kids Barreda Decode El C',
#  'Youth Breaknet 3.0',
#  'Infant Grand Court Minnie',
#  'Infant Chuck Taylor All Star Cribster',
#  'Kids X_Plrpath El',
#  'Kids Tensaur Run 3.0 El',
#  'Youth Air Max Fire Gs',
#  'Gs Official',
#  'Kids Fun Racer 2 Ac+ Ps',
#  'Infant Flexfocus Modern Ac+',
#  'Kids Gel-Nyc Ps',
#  'Kids Go Run 400 V2',
#  'Infant Adifom Samba 360 I',
#  'Kids Bounder',
#  'Kids Microspec Velocity',
#  'Kids Fortarun 4.0 El C',
#  '578 Sports Shoes',
#  'Nike Flex Runner 4',
#  'Youth Advantage Base 2.0',
#  'Kids Gt-1000 14 Ps',
#  'Kids 530',
#  'Kids Bounder',
#  'Kids Leadcat 2.0',
#  'Tensaur Comfort Shoes Kids',
#  'Nike Air Max Nova',
#  'Infant Grand Court 2.0',
#  'Adifom Adilette Slides Kids',
#  'Youth Cloud Sky',
#  'Kids Breakbase C',
#  'Youth P-6000 Bg',
#  'Youth Flex Runner 4 Gs',
#  'Youth Air Max 270 Bg',
#  'Youth Cosmic Runner Gs',
#  'Infant Fun Racer 2 Ac+',
#  'Nike Air Max SC',
#  'Nike Air Max Nova',
#  'Youth P-6000 Bg',
#  'Youth Air Max 270 Bg',
#  'Youth Soft Wired 2 Sliptech Ps',
#  'Infant Lightorama Rnr El',
#  'Youth Copa Pure IV Club FG',
#  'Kids All-Day Active Ac+ Ps',
#  'Youth Kruz Profoam Sliptech Aop',
#  'Youth Handball Spezial',
#  'NIKE COSMIC RUNNER GS',
#  'Kids Milano EVA  Narrow Fit Sandals',
#  'Kids Go Run 400 V2',
#  'Infant Tensaur Run 3.0 El',
#  'Kids Go Run 400 V2',
#  'Infant Duramo Sl2 El',
#  'Kids Adilette Estrap 2.0',
#  'Youth Soft Wired 2 Sliptech Ps',
#  'Youth Fortarun 4.0',
#  'Infant Lightorama Rnr El',
#  'Youth Copa Pure IV Club FG',
#  'Kids All-Day Active Ac+ Ps',
#  'COURT BOROUGH LOW RECRAFT BG',
#  'Youth Cosmic Runner Gs',
#  'Infant Handball Spezial Cf',
#  'Youth F50 Club TF',
#  'Infant Campus 00S Cf El',
#  'Kids Fisherman Sandals',
#  'Kids Star Runner 5 Ps',
#  'Kids Tensaur Sport 3.0',
#  'Infant Handball Spezial',
#  'Youth Court Borough Low Recraft Bg',
#  'Youth Crocband Clogs',
#  'Kids Arizona  BS Narrow Fit Sandals',
#  'Youth Dunk Low Retro Bttys',
#  'Youth Flexfocus Lite Modern',
#  'Youth Cloud Play',
#  'Youth Breakbase',
#  'Youth Suede Xl',
#  'Pale Blue Kids Pool Shoes',
#  'Tensaur Sport 2.0 Shoes',
#  'COURT BOROUGH LOW RECRAFT BTV',
#  'Youth Air Max Fire Gs',
#  'Kids 574',
#  'Youth F50 League TF',
#  'Kids Popcat 20',
#  'Kids Arizona EVA  Narrow Fit Sandals',
#  'Infant Advantagef',
#  'Kids Duramo Sl',
#  'Kids Evolve Run Sl Ac+ Ps',
#  'Kids Predator Club Ft El Fg/Mg',
#  'Youth Novablast 5 Gs',
#  'Kids Max Invigor Bp',
#  'Youth Jordan Spizike Low Bg',
#  'Kids Slide Sandals',
#  'Youth Air Max Bia Bg',
#  'Jordan Flight Court',
#  'Infant Japan S Ts',
#  'Youth Cosmic Runner Gs',
#  'Infant Campus 00S Cf El',
#  'Kids Fisherman Sandals',
#  'Infant Handball Spezial',
#  'Kids Popcat 20',
#  'Youth Dunk Low Se 1 Bg',
#  'Kids Tensaur Comfort Ac',
#  'Infant Lightorama Rnr El',
#  'Youth Campus 00S',
#  'Youth Giannis Immortality 4 Gs',
#  'Kids Jordan Max Aura 7 Bg',
#  'Youth P-6000 Bg',
#  'TEAM HUSTLE D 12 PS',
#  'Youth Air Max Phoenix Bg',
#  'Kids Lightorama Court El',
#  'Youth Future 9 Play FG',
#  'Youth 1906',
#  'Kids Grand Court Spider-Man El',
#  'Jordan 23/7.2 EasyOn SE',
#  'Infant Vortex 2.0',
#  'Youth Stellar Ride Gs',
#  'NIKE PACIFIC GS',
#  'AIR MAX 270 BG',
#  'Kids Handball Spezial Messi',
#  'Youth Air Max 90 Ltr Gs',
#  'Kids Air Max Bia Bp',
#  'Youth 9060',
#  'Youth Campio Xt',
#  'Youth Eclyptix 2000',
#  'Youth Runfalcon 6',
#  'Youth Revolution 7',
#  'Infant Runfalcon 6 El',
#  'Kids Predator Club Fg/Mg',
#  'Youth Free Ride Gs',
#  'Youth Air Max Bia Bg',
#  'Infant Grand Court 3.0 Bubble Cf',
#  'Youth Jordan Sixty Plus Low Bg',
#  'Jordan Session',
#  'Kids F50 Messi Club Tf',
#  'Youth Bgs Ascend',
#  'Junior Anthony Edwards 1 J Low',
#  'Kids Hoops Classic El',
#  'AIR ZOOM PEGASUS 42 GS',
#  'Youth Air Max Phoenix Bg',
#  'Youth Air Jordan 1 Mid Bg',
#  'Kids Copa Pure Iv League Tf',
#  'Youth Sonic Fly Gs',
#  'Kids F50 Hyperfast Club In',
#  'NIKE AIR MAX MOTO 2K BG',
#  'Kids F50 Messi Club Fg/Mg',
#  'Youth Tensaur Run 4.0',
#  'Youth Sonic Fly Gs',
#  'Kids Barreda Decode Jasm',
#  'Infant Grand Court Spider-Man Cf',
#  'Youth JN Old Skool',
#  'Youth Air Jordan 1 Mid Se Bg']

# %% [markdown]
# #### 6. Modify the previous `loop` to collect multiple web pages
# - In below code, we collect the web pages from 1 to 5 of that site
# - Notice that the only difference from page to page is the page number which we can use in the `for loop` with the formatted text f"

# %%
# define empty lists for your collections
titles = []
brands = []
prices = []
currencies = []
prereduction_prices = []
discounts = []
# your code here


hdr = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 YaBrowser/23.3.0.1922 (beta) Yowser/2.5 Safari/537.3-449"}

for page in range(1, 6):
    url = f'https://www.namshi.com/bahrain-en/kids-shoes-boys/?page={page}'
    html_page = requests.get(url, headers=hdr)
    soup = BeautifulSoup(html_page.text, 'html.parser')
    namshi = soup.find_all("div", class_="ProductBox_container__wiajf ProductBox_boxContainer__p7PaQ")

    for item in namshi:
        title = item.find("div", class_="ProductBox_productTitle__6tQ3b")
        if title is not None:
            titles.append(title.text)
        else:
            titles.append(None)

        brand = item.find("div", class_="OutletAndBrand_brandAndOutletTag__eEj4l")
        if brand is not None:
            brands.append(brand.text)
        else:
            brands.append(None)

        price = item.find("span", class_="ProductPrice_value__YcE7Z")
        if price is not None:
            prices.append(price.text)
        else:
            prices.append(None)

        currency = item.find("span", class_="ProductPrice_currency__zHaox")
        if currency is not None:
            currencies.append(currency.text)
        else:
            currencies.append(None)

        prereduction = item.find("div", class_="ProductPrice_preReductionPrice__oM4c9")
        if prereduction is not None:
            prereduction_prices.append(prereduction.text)
        else:
            prereduction_prices.append(None)

        discount = item.find("span", class_="DiscountTag_value__SofQj")
        if discount is not None:
            discounts.append(discount.text)
        else:
            discounts.append(None)

# %% [markdown]
# #### 7. Create a DataFrame to save all the scraped info. into a table.

# %%
namshi_df= pd.DataFrame({
    "Title": titles,
    "Brand": brands,
    "Price": prices,
    "Currency": currencies,
    "PreReduction_Price": prereduction_prices,
    "Discount": discounts
})

# %%
# display your dataframe
namshi_df.head(20)
# Out:
#                                 Title             Brand  Price Currency  \
# 0                           Youth 530       New Balance  52.25      BHD
# 1          Youth Copa Pure IV Club IN            Adidas  13.78      BHD
# 2                      Kids Breakbase            Adidas   18.9      BHD
# 3               Kids Handball Spezial  adidas Originals  20.38      BHD
# 4           Tensaur Switch Shoes Kids            Adidas   15.6      BHD
# 5         Kids Copa Pure Iv League Tf            Adidas  17.99      BHD
# 6                    Youth Gel-Nyc Gs             asics  49.51      BHD
# 7                   Kids Campus 00S C  adidas Originals  20.95      BHD
# 8                           Youth 408       New Balance  21.97      BHD
# 9              Youth Deportivo III TF            Adidas  13.78      BHD
# 10                  Youth Runfalcon 5            Adidas  18.78      BHD
# 11              Infant Samba Og Cf El  adidas Originals  22.42      BHD
# 12                   Air Jordan 1 Mid            Jordan  37.34      BHD
# 13                Kids Runfalcon 5 El            Adidas  16.39      BHD
# 14         Kids Chuck Taylor All Star          CONVERSE  14.57      BHD
# 15                      Youth Gazelle  adidas Originals  12.63      BHD
# 16  Nike Jr. Tiempo Legend 10 Academy              Nike  10.02      BHD
# 17                     AIR MAX 270 BG              Nike     28      BHD
# 18              Youth Tensaur Run 3.0            Adidas  11.95      BHD
# 19         Kids Chuck Taylor All Star          CONVERSE   11.5      BHD
#
#    PreReduction_Price Discount
# 0                 NaN      NaN
# 1               22.66     -40%
# 2               22.66     -17%
# 3               30.24     -33%
# 4               20.49     -24%
# 5               32.41     -45%
# 6               52.36      -6%
# 7               35.67     -42%
# 8               27.00     -19%
# 9               18.32     -25%
# 10              24.83     -25%
# 11              30.24     -26%
# 12              57.35     -35%
# 13              21.57     -25%
# 14              27.00     -47%
# 15              43.26     -71%
# 16              35.67     -72%
# 17              67.75     -59%
# 18              22.66     -48%
# 19              19.41     -41%

# %% [markdown]
# #### 8. Save your dataframe to a `CSV` file
# - Save the output to a csv file (excluding the index)

# %%
# Save the output to a csv file (excluding the index)
namshi_df.to_csv("namshi_kids_shoes.csv", index=False)
